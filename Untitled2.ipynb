# %% [markdown]
# <a href="https://colab.research.google.com/github/dpbasvs-afk/FUNNGROW-EVALUATION-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q -U "dagshub[jupyter]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.0/274.0 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 106.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 129.7 MB/s eta 0:00:00

# %%
from pathlib import Path
import dagshub

MOUNT_PATH = Path("/content/dagshub_storage")

mount_path = dagshub.storage.mount(
    REPO,
    path=MOUNT_PATH,
    cache=True
)

print("DagsHub storage mounted at:", mount_path)
# Out:
# Do you want to install all missing packages?
# Are you sure [y/(N)]: y
# Installing rclone...
# rclone installed successfully.
# Installing fusermount3...
# fusermount3 installed successfully.
# Accessing as dpbasvs-afk
# Successfully mounted DagsHub Storage in 'comfyui-project' to '/content/dagshub_storage'.
# To unmount, run `dagshub.storage.unmount(repo="dpbasvs-afk/comfyui-project", path="/content/dagshub_storage")`.
# DagsHub storage mounted at: /content/dagshub_storage

# %%
from pathlib import Path
import subprocess
import sys

COMFY_DIR = PERSISTENT_ROOT / "ComfyUI"

if (COMFY_DIR / "main.py").exists():
    print("ComfyUI already exists!")
else:
    subprocess.run([
        "git", "clone",
        "https://github.com/comfyanonymous/ComfyUI.git",
        str(COMFY_DIR)
    ], check=True)

print("ComfyUI location:", COMFY_DIR)
print("Exists:", (COMFY_DIR / "main.py").exists())
# Out:
# ComfyUI location: /content/dagshub_storage/comfyui_project/ComfyUI
# Exists: True
